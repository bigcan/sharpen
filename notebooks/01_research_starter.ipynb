# %% [markdown]
# # FinRL Pro Research Starter
#
# This notebook demonstrates running a small experiment via the FinRL Pro
# runner using a YAML config and recording a fingerprint.

# %%
from pathlib import Path
from finrl_pro.training.run_experiment import main as run_main

config = Path('finrl_pro/configs/experiments/sp500_daily.yaml')
run_main(['--config', str(config)])
