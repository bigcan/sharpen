# %% [markdown]
# # FinRL Podracer - Colab Entrypoint
#
# Use this notebook to set up and run your FinRL experiments on Google Colab.
#
# **Prerequisites:**
# 1. Run `python scripts/pack_for_colab.py` locally.
# 2. Upload `colab_package.zip` to the Files area in Colab (sidebar).

# %%
# 1. Unzip the package
# !unzip -q colab_package.zip
print("Package unzipped.")

# %%
# 2. Install Dependencies
# We install in editable mode so changes to the code are reflected immediately
# !pip install -e .

# Install additional system dependencies if needed (e.g., for TA-Lib or others)
# !apt-get install -y ...

# %%
# 3. Verify Installation
import sys
import os

# Add current directory to path just in case
sys.path.append(os.getcwd())

try:
    import finrl_pro
    print(f"Successfully imported finrl_pro version: {finrl_pro.__version__}")
except ImportError as e:
    print(f"Error importing finrl_pro: {e}")

# %%
# 4. Run Training (Example)
# Replace with your specific script
# !python scripts/run_phase8_training.py --help
